# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Box, Sequence, Dict
import numpy as np
import pandas as pd
from src.commons import methods
import statistics

from src.rl_environments.env_impr import EnvImpr
from src.model_approaches.analytical.oracle_fix_n import OracleFix_n
from src.model_approaches.analytical.oracle_var_n import OracleVar_n
from src.model_approaches.analytical.pto_fix_n import PTO_Fix_n
from src.model_approaches.analytical.pto_var_n import PTO_Var_n
from src.model_approaches.rl.ppo import PPO

from src.commons import generate_data
from src.commons.constants import AlphaEstimator, TravelTimeDist
import os
import pickle

# %% [markdown]
# ## Config

# %%
TRAIN_CONFIG = {
    'alpha_range': [ (1 + i / 10) for i in range(1,10)],
    'beta_range': [round(i * 0.5, 1) for i in range(2, 6)],
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MAX_LIKELI_GEN_GAMMA_UNBIAS,
}

TEST_CONFIG = {
    'alpha_range': [ (3 + i / 10) for i in range(1,10)],
    'beta_range': [round(i * 0.5, 1) for i in range(2, 6)],
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MAX_LIKELI_GEN_GAMMA_UNBIAS,
}

# %%
model_approaches = [PPO(EnvClass=EnvImpr, config=TRAIN_CONFIG, timesteps=500_000),
                    OracleVar_n(),
                    PTO_Var_n(TEST_CONFIG)
                   ] + [PTO_Fix_n(n, TEST_CONFIG) for n in [3, 5]] + [OracleFix_n(n) for n in [3, 5]]
test_df_path = generate_data.generate(config=TEST_CONFIG, row_count=10_000)
test_df = pd.DataFrame()
with open(test_df_path, 'rb') as f:
    test_df =pickle.load(f)
# Out:
# [INFO] Training PPO model...
# Saving to: /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImpr_5260d_500K.zip
# [INFO] Launching training with 8 parallel environments
# Using cpu device
# [INFO] Training PPO for 500000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.02     |
# |    ep_rew_mean     | -13.1    |
# | time/              |          |
# |    fps             | 893      |
# |    iterations      | 1        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.79        |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 983         |
# |    iterations           | 2           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010643305 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0403      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.9        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.57        |
# |    ep_rew_mean          | -13.8       |
# | time/                   |             |
# |    fps                  | 1027        |
# |    iterations           | 3           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010515888 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.373       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00505    |
# |    value_loss           | 75.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.59        |
# |    ep_rew_mean          | -15.3       |
# | time/                   |             |
# |    fps                  | 1058        |
# |    iterations           | 4           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009331342 |
# |    clip_fraction        | 0.0429      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0038     |
# |    value_loss           | 71          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.31        |
# |    ep_rew_mean          | -13         |
# | time/                   |             |
# |    fps                  | 1084        |
# |    iterations           | 5           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009704055 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00717    |
# |    value_loss           | 65.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.92         |
# |    ep_rew_mean          | -15.1        |
# | time/                   |              |
# |    fps                  | 1108         |
# |    iterations           | 6            |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0067620063 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.393        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.9         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00498     |
# |    value_loss           | 59.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.13        |
# |    ep_rew_mean          | -13.4       |
# | time/                   |             |
# |    fps                  | 1123        |
# |    iterations           | 7           |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.005323389 |
# |    clip_fraction        | 0.0498      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00512    |
# |    value_loss           | 55.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.3         |
# |    ep_rew_mean          | -14.2        |
# | time/                   |              |
# |    fps                  | 1131         |
# |    iterations           | 8            |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0068588303 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.44         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.5         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00593     |
# |    value_loss           | 51.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -13.9        |
# | time/                   |              |
# |    fps                  | 1144         |
# |    iterations           | 9            |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0041606813 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.41         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.6         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00558     |
# |    value_loss           | 45.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17          |
# |    ep_rew_mean          | -13.2       |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 10          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.007091022 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.5        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0059     |
# |    value_loss           | 40.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.3         |
# |    ep_rew_mean          | -15.8        |
# | time/                   |              |
# |    fps                  | 1165         |
# |    iterations           | 11           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0046212124 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.361        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.3         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00508     |
# |    value_loss           | 38.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.4         |
# |    ep_rew_mean          | -13.3        |
# | time/                   |              |
# |    fps                  | 1175         |
# |    iterations           | 12           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0051680515 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.334        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00427     |
# |    value_loss           | 37.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.3        |
# |    ep_rew_mean          | -12.9       |
# | time/                   |             |
# |    fps                  | 1191        |
# |    iterations           | 13          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.006978955 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.261       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 31.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.3        |
# |    ep_rew_mean          | -12.1       |
# | time/                   |             |
# |    fps                  | 1202        |
# |    iterations           | 14          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.009044909 |
# |    clip_fraction        | 0.0424      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.322       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.56        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0041     |
# |    value_loss           | 24.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.3         |
# |    ep_rew_mean          | -11.8        |
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 15           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0064166286 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.304        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.13         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00304     |
# |    value_loss           | 18.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.9        |
# |    ep_rew_mean          | -10.5       |
# | time/                   |             |
# |    fps                  | 1227        |
# |    iterations           | 16          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.008275112 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00402    |
# |    value_loss           | 17.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.5        |
# |    ep_rew_mean          | -11.4       |
# | time/                   |             |
# |    fps                  | 1238        |
# |    iterations           | 17          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.009576831 |
# |    clip_fraction        | 0.0403      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.73        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.8        |
# |    ep_rew_mean          | -8.95       |
# | time/                   |             |
# |    fps                  | 1249        |
# |    iterations           | 18          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.008321352 |
# |    clip_fraction        | 0.0427      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.83        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 13.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.6       |
# |    ep_rew_mean          | -10.9      |
# | time/                   |            |
# |    fps                  | 1258       |
# |    iterations           | 19         |
# |    time_elapsed         | 247        |
# |    total_timesteps      | 311296     |
# | train/                  |            |
# |    approx_kl            | 0.00666455 |
# |    clip_fraction        | 0.0412     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | 0.159      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.67       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00168   |
# |    value_loss           | 11.4       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 59.1         |
# |    ep_rew_mean          | -7.63        |
# | time/                   |              |
# |    fps                  | 1270         |
# |    iterations           | 20           |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0037916636 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.946       |
# |    explained_variance   | 0.238        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.31         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000749    |
# |    value_loss           | 11.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.8        |
# |    ep_rew_mean          | -10.5       |
# | time/                   |             |
# |    fps                  | 1279        |
# |    iterations           | 21          |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.005924249 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.75        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 8.05        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 54.5         |
# |    ep_rew_mean          | -9.12        |
# | time/                   |              |
# |    fps                  | 1291         |
# |    iterations           | 22           |
# |    time_elapsed         | 279          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0050960607 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.952       |
# |    explained_variance   | 0.184        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.74         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 9.75         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.2         |
# |    ep_rew_mean          | -9.56        |
# | time/                   |              |
# |    fps                  | 1299         |
# |    iterations           | 23           |
# |    time_elapsed         | 290          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0056608366 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | 0.263        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.53         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 7.75         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.5        |
# |    ep_rew_mean          | -9.51       |
# | time/                   |             |
# |    fps                  | 1308        |
# |    iterations           | 24          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.004305164 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.19        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00096    |
# |    value_loss           | 7.51        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 67.9         |
# |    ep_rew_mean          | -9.74        |
# | time/                   |              |
# |    fps                  | 1317         |
# |    iterations           | 25           |
# |    time_elapsed         | 311          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0033374568 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 0.366        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.77         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -2.89e-05    |
# |    value_loss           | 8.44         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 58.2         |
# |    ep_rew_mean          | -8.26        |
# | time/                   |              |
# |    fps                  | 1324         |
# |    iterations           | 26           |
# |    time_elapsed         | 321          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0045637093 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.878       |
# |    explained_variance   | 0.319        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.27         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 8.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 71.3         |
# |    ep_rew_mean          | -8.72        |
# | time/                   |              |
# |    fps                  | 1334         |
# |    iterations           | 27           |
# |    time_elapsed         | 331          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0028145742 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.904       |
# |    explained_variance   | 0.356        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.16         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -7.31e-05    |
# |    value_loss           | 7.9          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.5        |
# |    ep_rew_mean          | -9.77       |
# | time/                   |             |
# |    fps                  | 1341        |
# |    iterations           | 28          |
# |    time_elapsed         | 342         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.004488996 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.959      |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00168    |
# |    value_loss           | 6.9         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 71.9         |
# |    ep_rew_mean          | -7.49        |
# | time/                   |              |
# |    fps                  | 1347         |
# |    iterations           | 29           |
# |    time_elapsed         | 352          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0044890186 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.944       |
# |    explained_variance   | 0.324        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.42         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 10.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.6         |
# |    ep_rew_mean          | -9.45        |
# | time/                   |              |
# |    fps                  | 1352         |
# |    iterations           | 30           |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0049330993 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.907       |
# |    explained_variance   | 0.419        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.04         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 6.6          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.4        |
# |    ep_rew_mean          | -10.3       |
# | time/                   |             |
# |    fps                  | 1358        |
# |    iterations           | 31          |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.002932075 |
# |    clip_fraction        | 0.0149      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.66        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.000169    |
# |    value_loss           | 7.35        |
# -----------------------------------------
# [INFO] Model saved to /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImpr_5260d_500K.zip
# [INFO] Generating new dataset:
# /Users/preetkaria/PycharmProjects/when_to_leave/data/2505e_10K

# %%
from pandarallel import pandarallel

# Initialize pandarallel with progress bar enabled
pandarallel.initialize(progress_bar=True)

columns_to_visualize = []
for model in model_approaches:
    print(f'Evaluating {model.prediction_keys()}')
    columns_to_visualize += model.prediction_keys()
    
    new_cols = test_df.parallel_apply(lambda row: model.predict(row, override=False), result_type='expand', axis=1)
    for i, col_name in enumerate(model.prediction_keys()):
        test_df[col_name] = new_cols[i]
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# Evaluating ['cost_PPO_EnvImpr_5260d_500K', 'observed_n_PPO_EnvImpr_5260d_500K']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Var_n', 'observed_n_Oracle_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Var_n', 'observed_n_PTO_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …

# %%
from pathlib import Path
test_df_path = Path(test_df_path)
test_df.to_csv(test_df_path.with_suffix('.csv'), index=False)
test_df.to_pickle(test_df_path)

# %% [markdown]
# ## Visualize Results

# %%
import plotly.graph_objects as go

# columns_to_visualize = [x for x in test_df.columns if 'cost' in x or 'observe' in x]

# Calculate means
means = test_df[columns_to_visualize + ['h', 'c']].mean()

# Plot
fig = go.Figure(data=[go.Bar(x=means.index, y=means.values)])
fig.update_layout(title="Mean Values of Costs, H, and C", yaxis_title="Mean Value")
fig.show()

# Calculate medians
medians = test_df[columns_to_visualize + ['h', 'c']].median()

# Plot
fig = go.Figure(data=[go.Bar(x=medians.index, y=medians.values)])
fig.update_layout(title="Median Values of Costs, H, and C", yaxis_title="Median Value")
fig.show()

# Create a dataframe with two rows: one for means and one for medians
summary_df = pd.DataFrame({'Mean': means, 'Median': medians}).T
summary_df.head()
# Out:
#         cost_PPO_EnvImpr_5260d_500K  observed_n_PPO_EnvImpr_5260d_500K  \
# Mean                      16.633626                            11.4517
# Median                    11.276750                            10.0000
#
#         cost_Oracle_Var_n  observed_n_Oracle_Var_n  cost_PTO_Var_n  \
# Mean             9.298037                  11.0449       12.050424
# Median           7.391783                   9.0000        8.971660
#
#         observed_n_PTO_Var_n  cost_PTO_Fix_n_3  cost_PTO_Fix_n_5  \
# Mean                 10.7965         20.280072         17.018487
# Median                8.0000         25.000000         18.726209
#
#         cost_Oracle_Fix_n_3  cost_Oracle_Fix_n_5    h     c
# Mean              10.707781            12.116073  0.5  25.0
# Median             8.077128             9.083460  0.5  25.0
