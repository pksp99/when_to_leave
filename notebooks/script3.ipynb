# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Box, Sequence, Dict
import numpy as np
import pandas as pd
from src.commons import methods
import statistics

from src.rl_environments.env_impr import EnvImpr
from src.model_approaches.analytical.oracle_fix_n import OracleFix_n
from src.model_approaches.analytical.oracle_var_n import OracleVar_n
from src.model_approaches.analytical.pto_fix_n import PTO_Fix_n
from src.model_approaches.analytical.pto_var_n import PTO_Var_n
from src.model_approaches.rl.ppo import PPO

from src.commons import generate_data
from src.commons.constants import AlphaEstimator, TravelTimeDist
import os
import pickle

# %% [markdown]
# ## Config

# %%
TRAIN_CONFIG = {
    'alpha_range': [ (0 + i / 10) for i in range(1,10)],
    'beta_range': [round(i * 0.5, 1) for i in range(2, 6)],
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MAX_LIKELI_GEN_GAMMA_BIAS,
}

TEST_CONFIG = {
    'alpha_range': [ (3 + i / 10) for i in range(1,10)],
    'beta_range': [round(i * 0.5, 1) for i in range(2, 6)],
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MAX_LIKELI_GEN_GAMMA_BIAS,
}

# %%
model_approaches = [PPO(EnvClass=EnvImpr, config=TRAIN_CONFIG, timesteps=500_000),
                    OracleVar_n(),
                    PTO_Var_n(TEST_CONFIG)
                   ] + [PTO_Fix_n(n, TEST_CONFIG) for n in [3, 5]] + [OracleFix_n(n) for n in [3, 5]]
test_df_path = generate_data.generate(config=TEST_CONFIG, row_count=10_000)
test_df = pd.DataFrame()
with open(test_df_path, 'rb') as f:
    test_df =pickle.load(f)
# Out:
# [INFO] Training PPO model...
# Saving to: /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImpr_f41f5_500K.zip
# [INFO] Launching training with 8 parallel environments
# Using cpu device
# [INFO] Training PPO for 500000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.01     |
# |    ep_rew_mean     | -4.9     |
# | time/              |          |
# |    fps             | 451      |
# |    iterations      | 1        |
# |    time_elapsed    | 36       |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.01        |
# |    ep_rew_mean          | -5.06       |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 2           |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014455869 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0227     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.75        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00701    |
# |    value_loss           | 28.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.83        |
# |    ep_rew_mean          | -5.19       |
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 3           |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010537927 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 25          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.65       |
# |    ep_rew_mean          | -5.51      |
# | time/                   |            |
# |    fps                  | 329        |
# |    iterations           | 4          |
# |    time_elapsed         | 198        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00870762 |
# |    clip_fraction        | 0.0523     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.214      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22         |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00313   |
# |    value_loss           | 25.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.94        |
# |    ep_rew_mean          | -6.24       |
# | time/                   |             |
# |    fps                  | 322         |
# |    iterations           | 5           |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009161327 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.88        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00288    |
# |    value_loss           | 22.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.89         |
# |    ep_rew_mean          | -5.01        |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 6            |
# |    time_elapsed         | 306          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0069941096 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.255        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.2         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 22.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.7          |
# |    ep_rew_mean          | -4.98        |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 7            |
# |    time_elapsed         | 356          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0065509086 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.281        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.97         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 22.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.82         |
# |    ep_rew_mean          | -4.48        |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 8            |
# |    time_elapsed         | 404          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0066858316 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.298        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.54         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 20.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.46         |
# |    ep_rew_mean          | -5.44        |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 9            |
# |    time_elapsed         | 454          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0054040886 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.307        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.2         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 20           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.58        |
# |    ep_rew_mean          | -3.89       |
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 10          |
# |    time_elapsed         | 502         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.008547872 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.309       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.52        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00319    |
# |    value_loss           | 20          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.08        |
# |    ep_rew_mean          | -5.66       |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 11          |
# |    time_elapsed         | 549         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.006989845 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.15        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00274    |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.11        |
# |    ep_rew_mean          | -4.55       |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 12          |
# |    time_elapsed         | 597         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.007416057 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.79        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 18.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.59        |
# |    ep_rew_mean          | -4.65       |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 13          |
# |    time_elapsed         | 643         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.008913075 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.13        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 17.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.1         |
# |    ep_rew_mean          | -4.65        |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 14           |
# |    time_elapsed         | 686          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0055142534 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.14         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 14.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.4        |
# |    ep_rew_mean          | -5.06       |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 15          |
# |    time_elapsed         | 730         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.008144601 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.95        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00336    |
# |    value_loss           | 14.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.31        |
# |    ep_rew_mean          | -4.53       |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 16          |
# |    time_elapsed         | 774         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.007935172 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 14.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.7        |
# |    ep_rew_mean          | -5.76       |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 17          |
# |    time_elapsed         | 817         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.008366149 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.82        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 13.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.8        |
# |    ep_rew_mean          | -5.01       |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 18          |
# |    time_elapsed         | 857         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.008602776 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.156       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.59        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 12.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.1         |
# |    ep_rew_mean          | -4.83        |
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 19           |
# |    time_elapsed         | 898          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0057253605 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.44         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 12           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.3         |
# |    ep_rew_mean          | -4.92        |
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 20           |
# |    time_elapsed         | 933          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0065547223 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 9            |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.2         |
# |    ep_rew_mean          | -4.83        |
# | time/                   |              |
# |    fps                  | 353          |
# |    iterations           | 21           |
# |    time_elapsed         | 972          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0050711106 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.0663       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.43         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 10.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.1        |
# |    ep_rew_mean          | -4.85       |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 22          |
# |    time_elapsed         | 1003        |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.005587213 |
# |    clip_fraction        | 0.0463      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.53        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000396   |
# |    value_loss           | 8.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.3        |
# |    ep_rew_mean          | -4.99       |
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 23          |
# |    time_elapsed         | 1042        |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.007062152 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.0745      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00095    |
# |    value_loss           | 8.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.3        |
# |    ep_rew_mean          | -4.39       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 24          |
# |    time_elapsed         | 1077        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.009719012 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.68        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 6.8         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.6         |
# |    ep_rew_mean          | -4.09        |
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 25           |
# |    time_elapsed         | 1104         |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0053663184 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.93         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000746    |
# |    value_loss           | 8.17         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.6         |
# |    ep_rew_mean          | -5.1         |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 26           |
# |    time_elapsed         | 1120         |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0052610133 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.969       |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.891        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 6.6          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.4         |
# |    ep_rew_mean          | -4.12        |
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 27           |
# |    time_elapsed         | 1130         |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0045734425 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | 0.0954       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000468    |
# |    value_loss           | 6.35         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.1         |
# |    ep_rew_mean          | -4.32        |
# | time/                   |              |
# |    fps                  | 402          |
# |    iterations           | 28           |
# |    time_elapsed         | 1140         |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0062606717 |
# |    clip_fraction        | 0.0582       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.966       |
# |    explained_variance   | 0.063        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.28         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 6.9          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.3         |
# |    ep_rew_mean          | -4.53        |
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 29           |
# |    time_elapsed         | 1151         |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0049708346 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.971       |
# |    explained_variance   | 0.106        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.28         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000436    |
# |    value_loss           | 6.93         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.3         |
# |    ep_rew_mean          | -3.77        |
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 30           |
# |    time_elapsed         | 1161         |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0047210753 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.956       |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.67         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000266    |
# |    value_loss           | 8.36         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.8         |
# |    ep_rew_mean          | -4.99        |
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 31           |
# |    time_elapsed         | 1171         |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0051143793 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.973       |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.22         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00025     |
# |    value_loss           | 8.23         |
# ------------------------------------------
# [INFO] Model saved to /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImpr_f41f5_500K.zip
# [INFO] Generating new dataset:
# /Users/preetkaria/PycharmProjects/when_to_leave/data/bfe02_10K

# %%
from pandarallel import pandarallel

# Initialize pandarallel with progress bar enabled
pandarallel.initialize(progress_bar=True)

columns_to_visualize = []
for model in model_approaches:
    print(f'Evaluating {model.prediction_keys()}')
    columns_to_visualize += model.prediction_keys()
    
    new_cols = test_df.parallel_apply(lambda row: model.predict(row, override=False), result_type='expand', axis=1)
    for i, col_name in enumerate(model.prediction_keys()):
        test_df[col_name] = new_cols[i]
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# Evaluating ['cost_PPO_EnvImpr_f41f5_500K', 'observed_n_PPO_EnvImpr_f41f5_500K']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Var_n', 'observed_n_Oracle_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Var_n', 'observed_n_PTO_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 17
#      13         test_df[col_name] = new_cols[i]
#      16 # Save the test_df with predictions
# ---> 17 test_df.to_csv(test_df_path.with_suffix('.csv'), index=False)
#      18 test_df.to_pickle(test_df_path)
#
# AttributeError: 'str' object has no attribute 'with_suffix'

# %%
from pathlib import Path
test_df_path = Path(test_df_path)
test_df.to_csv(test_df_path.with_suffix('.csv'), index=False)
test_df.to_pickle(test_df_path)

# %% [markdown]
# ## Visualize Results

# %%
import plotly.graph_objects as go

# columns_to_visualize = [x for x in test_df.columns if 'cost' in x or 'observe' in x]

# Calculate means
means = test_df[columns_to_visualize + ['h', 'c']].mean()

# Plot
fig = go.Figure(data=[go.Bar(x=means.index, y=means.values)])
fig.update_layout(title="Mean Values of Costs, H, and C", yaxis_title="Mean Value")
fig.show()

# Calculate medians
medians = test_df[columns_to_visualize + ['h', 'c']].median()

# Plot
fig = go.Figure(data=[go.Bar(x=medians.index, y=medians.values)])
fig.update_layout(title="Median Values of Costs, H, and C", yaxis_title="Median Value")
fig.show()

# Create a dataframe with two rows: one for means and one for medians
summary_df = pd.DataFrame({'Mean': means, 'Median': medians}).T
summary_df.head()
# Out:
#         cost_PPO_EnvImpr_f41f5_500K  observed_n_PPO_EnvImpr_f41f5_500K  \
# Mean                      12.539414                            10.2523
# Median                     9.499099                             8.0000
#
#         cost_Oracle_Var_n  observed_n_Oracle_Var_n  cost_PTO_Var_n  \
# Mean             9.403344                  10.9592       11.658395
# Median           7.385171                   9.0000        8.161354
#
#         observed_n_PTO_Var_n  cost_PTO_Fix_n_3  cost_PTO_Fix_n_5  \
# Mean                 10.9947         23.507961          3.521075
# Median                9.0000         23.507961          3.521075
#
#         cost_Oracle_Fix_n_3  cost_Oracle_Fix_n_5    h     c
# Mean              14.114047            11.443581  0.5  25.0
# Median            14.114047            11.443581  0.5  25.0
