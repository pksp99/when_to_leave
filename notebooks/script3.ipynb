# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Box, Sequence, Dict
import numpy as np
import pandas as pd
from src.commons import methods
import statistics

from src.rl_environments.env_impr import EnvImpr
from src.model_approaches.analytical.oracle_fix_n import OracleFix_n
from src.model_approaches.analytical.oracle_var_n import OracleVar_n
from src.model_approaches.analytical.pto_fix_n import PTO_Fix_n
from src.model_approaches.analytical.pto_var_n import PTO_Var_n
from src.model_approaches.rl.ppo import PPO

from src.commons import generate_data
from src.commons.constants import AlphaEstimator, TravelTimeDist
import os
import pickle

# %% [markdown]
# ## Config

# %%
TRAIN_CONFIG = {
    'alpha_range': [ (1 + i / 10) for i in range(1,10)],
    'beta_range': [round(i * 0.5, 1) for i in range(2, 6)],
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MAX_LIKELI_GEN_GAMMA_BIAS,
}

TEST_CONFIG = {
    'alpha_range': [ (3 + i / 10) for i in range(1,10)],
    'beta_range': [round(i * 0.5, 1) for i in range(2, 6)],
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MAX_LIKELI_GEN_GAMMA_BIAS,
}

# %%
model_approaches = [PPO(EnvClass=EnvImpr, config=TRAIN_CONFIG, timesteps=500_000),
                    OracleVar_n(),
                    PTO_Var_n(TEST_CONFIG)
                   ] + [PTO_Fix_n(n, TEST_CONFIG) for n in [3, 5]] + [OracleFix_n(n) for n in [3, 5]]
test_df_path = generate_data.generate(config=TEST_CONFIG, row_count=10_000)
test_df = pd.DataFrame()
with open(test_df_path, 'rb') as f:
    test_df =pickle.load(f)
# Out:
# [INFO] Training PPO model...
# Saving to: /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImpr_88bb5_500K.zip
# [INFO] Launching training with 8 parallel environments
# Using cpu device
# [INFO] Training PPO for 500000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.11     |
# |    ep_rew_mean     | -13.9    |
# | time/              |          |
# |    fps             | 446      |
# |    iterations      | 1        |
# |    time_elapsed    | 36       |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.64        |
# |    ep_rew_mean          | -12.7       |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 2           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011117364 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0686     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.3        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 102         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45         |
# |    ep_rew_mean          | -12.9        |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 3            |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0061181737 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.414        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.5         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00426     |
# |    value_loss           | 63.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.51        |
# |    ep_rew_mean          | -14.5       |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 4           |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007157252 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00426    |
# |    value_loss           | 64.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.63        |
# |    ep_rew_mean          | -13.3       |
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 5           |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010388776 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 54.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.74         |
# |    ep_rew_mean          | -13.6        |
# | time/                   |              |
# |    fps                  | 517          |
# |    iterations           | 6            |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0058374978 |
# |    clip_fraction        | 0.0501       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.49         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.8         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00487     |
# |    value_loss           | 57.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | -15.2       |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 7           |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.008012922 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00556    |
# |    value_loss           | 51          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.8       |
# |    ep_rew_mean          | -11.2      |
# | time/                   |            |
# |    fps                  | 544        |
# |    iterations           | 8          |
# |    time_elapsed         | 240        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.00532564 |
# |    clip_fraction        | 0.0444     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.453      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.6       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00493   |
# |    value_loss           | 52.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | -15.3        |
# | time/                   |              |
# |    fps                  | 560          |
# |    iterations           | 9            |
# |    time_elapsed         | 263          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0059469393 |
# |    clip_fraction        | 0.0527       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.443        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.2         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00546     |
# |    value_loss           | 42.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -12.7       |
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 10          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.008335231 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00622    |
# |    value_loss           | 37.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.6        |
# |    ep_rew_mean          | -11.4       |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 11          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.006661848 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00446    |
# |    value_loss           | 34.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.5         |
# |    ep_rew_mean          | -13          |
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 12           |
# |    time_elapsed         | 323          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0034742001 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.456        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 30.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.1         |
# |    ep_rew_mean          | -14.7        |
# | time/                   |              |
# |    fps                  | 623          |
# |    iterations           | 13           |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0062250537 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.447        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.2         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00496     |
# |    value_loss           | 33.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.7         |
# |    ep_rew_mean          | -12          |
# | time/                   |              |
# |    fps                  | 636          |
# |    iterations           | 14           |
# |    time_elapsed         | 360          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0056237495 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.455        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.06         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00472     |
# |    value_loss           | 27.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.4        |
# |    ep_rew_mean          | -9.49       |
# | time/                   |             |
# |    fps                  | 648         |
# |    iterations           | 15          |
# |    time_elapsed         | 378         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.004420592 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 27          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.5         |
# |    ep_rew_mean          | -9.77        |
# | time/                   |              |
# |    fps                  | 640          |
# |    iterations           | 16           |
# |    time_elapsed         | 409          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0051484955 |
# |    clip_fraction        | 0.0441       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.334        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.31         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 17           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52          |
# |    ep_rew_mean          | -9.73       |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 17          |
# |    time_elapsed         | 438         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.006889724 |
# |    clip_fraction        | 0.0274      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.15        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 16.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.9        |
# |    ep_rew_mean          | -8.38       |
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 18          |
# |    time_elapsed         | 465         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.008926314 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.17        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 11.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.8        |
# |    ep_rew_mean          | -8.99       |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 19          |
# |    time_elapsed         | 494         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.003290927 |
# |    clip_fraction        | 0.0212      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.2         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000764   |
# |    value_loss           | 9.85        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 55.8         |
# |    ep_rew_mean          | -10.4        |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 20           |
# |    time_elapsed         | 523          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0045679873 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.24         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 9.51         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.9        |
# |    ep_rew_mean          | -9.15       |
# | time/                   |             |
# |    fps                  | 627         |
# |    iterations           | 21          |
# |    time_elapsed         | 548         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.006167542 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00177    |
# |    value_loss           | 10.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.1        |
# |    ep_rew_mean          | -7.59       |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 22          |
# |    time_elapsed         | 575         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.005624626 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00109    |
# |    value_loss           | 6.99        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53.4         |
# |    ep_rew_mean          | -7.14        |
# | time/                   |              |
# |    fps                  | 622          |
# |    iterations           | 23           |
# |    time_elapsed         | 605          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0062420624 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.872       |
# |    explained_variance   | 0.236        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.74         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 7.83         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.5        |
# |    ep_rew_mean          | -9.57       |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 24          |
# |    time_elapsed         | 634         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.003918128 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.868      |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.48        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000343   |
# |    value_loss           | 7.72        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67          |
# |    ep_rew_mean          | -8.67       |
# | time/                   |             |
# |    fps                  | 618         |
# |    iterations           | 25          |
# |    time_elapsed         | 661         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.002627149 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.781      |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.61        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -5.95e-05   |
# |    value_loss           | 8.55        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.5        |
# |    ep_rew_mean          | -8.96       |
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 26          |
# |    time_elapsed         | 690         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.004309811 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | 0.377       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.72        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000418   |
# |    value_loss           | 6.44        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.4         |
# |    ep_rew_mean          | -8.71        |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 27           |
# |    time_elapsed         | 718          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0041519916 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.774       |
# |    explained_variance   | 0.33         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.26         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000734    |
# |    value_loss           | 11.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 67.7         |
# |    ep_rew_mean          | -9.07        |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 28           |
# |    time_elapsed         | 747          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0018894896 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.7         |
# |    explained_variance   | 0.396        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.93         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.000172     |
# |    value_loss           | 6.95         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 64.3         |
# |    ep_rew_mean          | -7.7         |
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 29           |
# |    time_elapsed         | 775          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0026672704 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.724       |
# |    explained_variance   | 0.429        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.89         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000826    |
# |    value_loss           | 7.41         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.4        |
# |    ep_rew_mean          | -8.76       |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 30          |
# |    time_elapsed         | 800         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.003277021 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.678      |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.41        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.000121    |
# |    value_loss           | 6.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67.6        |
# |    ep_rew_mean          | -7.82       |
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 31          |
# |    time_elapsed         | 834         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.003916309 |
# |    clip_fraction        | 0.0346      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.624      |
# |    explained_variance   | 0.393       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.41        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.000137   |
# |    value_loss           | 6.49        |
# -----------------------------------------
# [INFO] Model saved to /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImpr_88bb5_500K.zip
# [INFO] Generating new dataset:
# /Users/preetkaria/PycharmProjects/when_to_leave/data/bfe02_10K

# %%
from pandarallel import pandarallel

# Initialize pandarallel with progress bar enabled
pandarallel.initialize(progress_bar=True)

columns_to_visualize = []
for model in model_approaches:
    print(f'Evaluating {model.prediction_keys()}')
    columns_to_visualize += model.prediction_keys()
    
    new_cols = test_df.parallel_apply(lambda row: model.predict(row, override=False), result_type='expand', axis=1)
    for i, col_name in enumerate(model.prediction_keys()):
        test_df[col_name] = new_cols[i]
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# Evaluating ['cost_PPO_EnvImpr_88bb5_500K', 'observed_n_PPO_EnvImpr_88bb5_500K']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Var_n', 'observed_n_Oracle_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Var_n', 'observed_n_PTO_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …

# %%
from pathlib import Path
test_df_path = Path(test_df_path)
test_df.to_csv(test_df_path.with_suffix('.csv'), index=False)
test_df.to_pickle(test_df_path)

# %% [markdown]
# ## Visualize Results

# %%
import plotly.graph_objects as go

# columns_to_visualize = [x for x in test_df.columns if 'cost' in x or 'observe' in x]

# Calculate means
means = test_df[columns_to_visualize + ['h', 'c']].mean()

# Plot
fig = go.Figure(data=[go.Bar(x=means.index, y=means.values)])
fig.update_layout(title="Mean Values of Costs, H, and C", yaxis_title="Mean Value")
fig.show()

# Calculate medians
medians = test_df[columns_to_visualize + ['h', 'c']].median()

# Plot
fig = go.Figure(data=[go.Bar(x=medians.index, y=medians.values)])
fig.update_layout(title="Median Values of Costs, H, and C", yaxis_title="Median Value")
fig.show()

# Create a dataframe with two rows: one for means and one for medians
summary_df = pd.DataFrame({'Mean': means, 'Median': medians}).T
summary_df.head()
# Out:
#         cost_PPO_EnvImpr_88bb5_500K  observed_n_PPO_EnvImpr_88bb5_500K  \
# Mean                      12.113384                            11.4797
# Median                     8.530774                             9.0000
#
#         cost_Oracle_Var_n  observed_n_Oracle_Var_n  cost_PTO_Var_n  \
# Mean             9.396165                  11.0491       11.493681
# Median           7.360193                   9.0000        7.881395
#
#         observed_n_PTO_Var_n  cost_PTO_Fix_n_3  cost_PTO_Fix_n_5  \
# Mean                  11.141         18.139448         16.945154
# Median                 9.000         21.421250         19.111953
#
#         cost_Oracle_Fix_n_3  cost_Oracle_Fix_n_5    h     c
# Mean              10.833485            12.068516  0.5  25.0
# Median             8.269001             9.243081  0.5  25.0
