# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Box, Sequence, Dict
import numpy as np
import pandas as pd
from src.commons import methods
import statistics

from src.rl_environments.env_impr import EnvImpr
from src.model_approaches.analytical.oracle_fix_n import OracleFix_n
from src.model_approaches.analytical.oracle_var_n import OracleVar_n
from src.model_approaches.analytical.pto_fix_n import PTO_Fix_n
from src.model_approaches.analytical.pto_var_n import PTO_Var_n
from src.model_approaches.rl.ppo import PPO

from src.commons import generate_data
from src.commons.constants import AlphaEstimator, TravelTimeDist
import os
import pickle

# %% [markdown]
# ## Config

# %%
TRAIN_CONFIG = {
    'alpha_range': [ (1 + i / 10) for i in range(1,10)],
    'beta_range': [round(i * 0.5, 1) for i in range(2, 6)],
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MOMENTS,
}

TEST_CONFIG = {
    'alpha_range': [ (1 + i / 10) for i in range(1,10)],
    'beta_range': [round(i * 0.5, 1) for i in range(2, 6)],
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MOMENTS,
}

# %%
model_approaches = [PPO(EnvClass=EnvImpr, config=TRAIN_CONFIG, timesteps=500_000),
                    OracleVar_n(),
                    PTO_Var_n(TEST_CONFIG)
                   ] + [PTO_Fix_n(n, TEST_CONFIG) for n in [3, 5]] + [OracleFix_n(n) for n in [3, 5]]
test_df_path = generate_data.generate(config=TEST_CONFIG, row_count=10_000)
test_df = pd.DataFrame()
with open(test_df_path, 'rb') as f:
    test_df =pickle.load(f)
# Out:
# [INFO] Training PPO model...
# Saving to: /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImpr_9a770_500K.zip
# [INFO] Launching training with 8 parallel environments
# Using cpu device
# [INFO] Training PPO for 500000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.33     |
# |    ep_rew_mean     | -14.7    |
# | time/              |          |
# |    fps             | 639      |
# |    iterations      | 1        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.76        |
# |    ep_rew_mean          | -12.9       |
# | time/                   |             |
# |    fps                  | 650         |
# |    iterations           | 2           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012002362 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.035      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.4        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 98.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.91       |
# |    ep_rew_mean          | -14.5      |
# | time/                   |            |
# |    fps                  | 646        |
# |    iterations           | 3          |
# |    time_elapsed         | 76         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00749695 |
# |    clip_fraction        | 0.0462     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.439      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 28         |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00482   |
# |    value_loss           | 64.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.19        |
# |    ep_rew_mean          | -13.4       |
# | time/                   |             |
# |    fps                  | 662         |
# |    iterations           | 4           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008766968 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00493    |
# |    value_loss           | 60          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.58        |
# |    ep_rew_mean          | -13.4       |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 5           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010035383 |
# |    clip_fraction        | 0.0679      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 58.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.75        |
# |    ep_rew_mean          | -14.9       |
# | time/                   |             |
# |    fps                  | 688         |
# |    iterations           | 6           |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006926026 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.6        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 46.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.3        |
# |    ep_rew_mean          | -14.8       |
# | time/                   |             |
# |    fps                  | 701         |
# |    iterations           | 7           |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.008279389 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 51          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.5        |
# |    ep_rew_mean          | -14         |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 8           |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.010061555 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.6        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 48.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.8        |
# |    ep_rew_mean          | -13.3       |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 9           |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.006557337 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.8        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00641    |
# |    value_loss           | 44.7        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 23.1      |
# |    ep_rew_mean          | -13.6     |
# | time/                   |           |
# |    fps                  | 756       |
# |    iterations           | 10        |
# |    time_elapsed         | 216       |
# |    total_timesteps      | 163840    |
# | train/                  |           |
# |    approx_kl            | 0.0111816 |
# |    clip_fraction        | 0.064     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.13     |
# |    explained_variance   | 0.467     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 18.8      |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -0.00575  |
# |    value_loss           | 39.5      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24          |
# |    ep_rew_mean          | -13.7       |
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 11          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.005338191 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00387    |
# |    value_loss           | 31.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27          |
# |    ep_rew_mean          | -13.7       |
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 12          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.007079878 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.6        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00486    |
# |    value_loss           | 36.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -13         |
# | time/                   |             |
# |    fps                  | 805         |
# |    iterations           | 13          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.007335973 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 22.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.2         |
# |    ep_rew_mean          | -11          |
# | time/                   |              |
# |    fps                  | 825          |
# |    iterations           | 14           |
# |    time_elapsed         | 277          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0042061573 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.239        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.95         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00407     |
# |    value_loss           | 22           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.9        |
# |    ep_rew_mean          | -9.49       |
# | time/                   |             |
# |    fps                  | 841         |
# |    iterations           | 15          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.002412798 |
# |    clip_fraction        | 0.0166      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.03        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 12.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.6         |
# |    ep_rew_mean          | -11.2        |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 16           |
# |    time_elapsed         | 304          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0070711356 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.95         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 12.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 64           |
# |    ep_rew_mean          | -8.97        |
# | time/                   |              |
# |    fps                  | 874          |
# |    iterations           | 17           |
# |    time_elapsed         | 318          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0030492996 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.162        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.83         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 12.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.4         |
# |    ep_rew_mean          | -7.91        |
# | time/                   |              |
# |    fps                  | 891          |
# |    iterations           | 18           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0047080503 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.151        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.94         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 11.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 66.3         |
# |    ep_rew_mean          | -8.16        |
# | time/                   |              |
# |    fps                  | 902          |
# |    iterations           | 19           |
# |    time_elapsed         | 345          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0041879993 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.4          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 8.06         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 68           |
# |    ep_rew_mean          | -10.2        |
# | time/                   |              |
# |    fps                  | 914          |
# |    iterations           | 20           |
# |    time_elapsed         | 358          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0060992106 |
# |    clip_fraction        | 0.0276       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.152        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.66         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000766    |
# |    value_loss           | 8.61         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79.6         |
# |    ep_rew_mean          | -8.87        |
# | time/                   |              |
# |    fps                  | 932          |
# |    iterations           | 21           |
# |    time_elapsed         | 369          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0045324853 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.16         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000869    |
# |    value_loss           | 9.09         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67.5        |
# |    ep_rew_mean          | -9.53       |
# | time/                   |             |
# |    fps                  | 944         |
# |    iterations           | 22          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.008699432 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.92        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000905   |
# |    value_loss           | 7.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.8        |
# |    ep_rew_mean          | -8.09       |
# | time/                   |             |
# |    fps                  | 956         |
# |    iterations           | 23          |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.004903183 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.38        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.16        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00177    |
# |    value_loss           | 7.15        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 67.6         |
# |    ep_rew_mean          | -8.69        |
# | time/                   |              |
# |    fps                  | 967          |
# |    iterations           | 24           |
# |    time_elapsed         | 406          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0050217398 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.992       |
# |    explained_variance   | 0.328        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.9          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000208    |
# |    value_loss           | 6.77         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 70.2         |
# |    ep_rew_mean          | -9.25        |
# | time/                   |              |
# |    fps                  | 977          |
# |    iterations           | 25           |
# |    time_elapsed         | 419          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0077738455 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.964       |
# |    explained_variance   | 0.344        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.75         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000701    |
# |    value_loss           | 6.73         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.2        |
# |    ep_rew_mean          | -8.58       |
# | time/                   |             |
# |    fps                  | 987         |
# |    iterations           | 26          |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.003957426 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.969      |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 7.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.9        |
# |    ep_rew_mean          | -7.56       |
# | time/                   |             |
# |    fps                  | 999         |
# |    iterations           | 27          |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.005095052 |
# |    clip_fraction        | 0.0215      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000281   |
# |    value_loss           | 8.38        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 65.6         |
# |    ep_rew_mean          | -10.4        |
# | time/                   |              |
# |    fps                  | 1006         |
# |    iterations           | 28           |
# |    time_elapsed         | 455          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0048080906 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.985       |
# |    explained_variance   | 0.441        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.51         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.000114     |
# |    value_loss           | 5.14         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61.7         |
# |    ep_rew_mean          | -8.44        |
# | time/                   |              |
# |    fps                  | 1014         |
# |    iterations           | 29           |
# |    time_elapsed         | 468          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0067449734 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.973       |
# |    explained_variance   | 0.324        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.29         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000443    |
# |    value_loss           | 9.4          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.7         |
# |    ep_rew_mean          | -8.72        |
# | time/                   |              |
# |    fps                  | 1023         |
# |    iterations           | 30           |
# |    time_elapsed         | 480          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0053890254 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.97        |
# |    explained_variance   | 0.362        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.58         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 4.76e-05     |
# |    value_loss           | 7.57         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.2         |
# |    ep_rew_mean          | -8.81        |
# | time/                   |              |
# |    fps                  | 1027         |
# |    iterations           | 31           |
# |    time_elapsed         | 494          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0044877734 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.955       |
# |    explained_variance   | 0.319        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.28         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000801    |
# |    value_loss           | 7.51         |
# ------------------------------------------
# [INFO] Model saved to /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImpr_9a770_500K.zip
# [INFO] Generating new dataset:
# /Users/preetkaria/PycharmProjects/when_to_leave/data/882e8_10K

# %%
from pandarallel import pandarallel

# Initialize pandarallel with progress bar enabled
pandarallel.initialize(progress_bar=True)

columns_to_visualize = []
for model in model_approaches:
    print(f'Evaluating {model.prediction_keys()}')
    columns_to_visualize += model.prediction_keys()
    
    new_cols = test_df.parallel_apply(lambda row: model.predict(row, override=False), result_type='expand', axis=1)
    for i, col_name in enumerate(model.prediction_keys()):
        test_df[col_name] = new_cols[i]
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# Evaluating ['cost_PPO_EnvImpr_9a770_500K', 'observed_n_PPO_EnvImpr_9a770_500K']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Var_n', 'observed_n_Oracle_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Var_n', 'observed_n_PTO_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …

# %%
from pathlib import Path
test_df_path = Path(test_df_path)
test_df.to_csv(test_df_path.with_suffix('.csv'), index=False)
test_df.to_pickle(test_df_path)

# %% [markdown]
# ## Visualize Results

# %%
import plotly.graph_objects as go

# columns_to_visualize = [x for x in test_df.columns if 'cost' in x or 'observe' in x]

# Calculate means
means = test_df[columns_to_visualize + ['h', 'c']].mean()

# Plot
fig = go.Figure(data=[go.Bar(x=means.index, y=means.values)])
fig.update_layout(title="Mean Values of Costs, H, and C", yaxis_title="Mean Value")
fig.show()

# Calculate medians
medians = test_df[columns_to_visualize + ['h', 'c']].median()

# Plot
fig = go.Figure(data=[go.Bar(x=medians.index, y=medians.values)])
fig.update_layout(title="Median Values of Costs, H, and C", yaxis_title="Median Value")
fig.show()

# Create a dataframe with two rows: one for means and one for medians
summary_df = pd.DataFrame({'Mean': means, 'Median': medians}).T
summary_df.head()
# Out:
#         cost_PPO_EnvImpr_9a770_500K  observed_n_PPO_EnvImpr_9a770_500K  \
# Mean                      12.131281                            12.0052
# Median                     8.285667                            10.0000
#
#         cost_Oracle_Var_n  observed_n_Oracle_Var_n  cost_PTO_Var_n  \
# Mean             9.293548                  11.1262       11.545526
# Median           7.290631                   9.0000        8.071531
#
#         observed_n_PTO_Var_n  cost_PTO_Fix_n_3  cost_PTO_Fix_n_5  \
# Mean                 11.1513         18.089813         16.730256
# Median                9.0000         20.444702         18.019050
#
#         cost_Oracle_Fix_n_3  cost_Oracle_Fix_n_5    h     c
# Mean              10.671671            11.891176  0.5  25.0
# Median             8.114443             8.888797  0.5  25.0
