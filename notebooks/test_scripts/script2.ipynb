# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Box, Sequence, Dict
import numpy as np
import pandas as pd
from src.commons import methods
import statistics

from src.rl_environments.env_impr_ab import EnvImprAB
from src.model_approaches.analytical.oracle_fix_n import OracleFix_n
from src.model_approaches.analytical.oracle_var_n import OracleVar_n
from src.model_approaches.analytical.pto_fix_n import PTO_Fix_n
from src.model_approaches.analytical.pto_var_n import PTO_Var_n
from src.model_approaches.rl.ppo import PPO

from src.commons import generate_data
from src.commons.constants import AlphaEstimator, TravelTimeDist
import os
import pickle

# %% [markdown]
# ## Config

# %%
TRAIN_CONFIG = {
    'alpha_range': list(range(1, 7, 0.2)),
    'beta_range': list(range(1, 4, 0.2)),
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MAX_LIKELI,
}

TEST_CONFIG = {
    'alpha_range': [ (3 + i / 10) for i in range(1,10)],
    'beta_range': [round(i * 0.5, 1) for i in range(2, 6)],
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MAX_LIKELI,
}

# %%
model_approaches = [PPO(EnvClass=EnvImprAB, config=TRAIN_CONFIG, timesteps=2000_000),
                    OracleVar_n(),
                    PTO_Var_n(TEST_CONFIG)
                   ] + [PTO_Fix_n(n, TEST_CONFIG) for n in [3, 5]] + [OracleFix_n(n) for n in [3, 5]]
test_df_path = generate_data.generate(config=TEST_CONFIG, row_count=10_000)
test_df = pd.DataFrame()
with open(test_df_path, 'rb') as f:
    test_df =pickle.load(f)
# Out:
# [INFO] Training PPO model...
# Saving to: /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImprAB_a88ac_1M.zip
# [INFO] Launching training with 8 parallel environments
# Using cpu device
# [INFO] Training PPO for 1000000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.34     |
# |    ep_rew_mean     | -38.5    |
# | time/              |          |
# |    fps             | 351      |
# |    iterations      | 1        |
# |    time_elapsed    | 46       |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.72         |
# |    ep_rew_mean          | -30.3        |
# | time/                   |              |
# |    fps                  | 368          |
# |    iterations           | 2            |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0118698515 |
# |    clip_fraction        | 0.191        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000881     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 388          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 666          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.52        |
# |    ep_rew_mean          | -32         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 3           |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011704769 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.358       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00797    |
# |    value_loss           | 419         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.76        |
# |    ep_rew_mean          | -34.7       |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 4           |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007201841 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 212         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00516    |
# |    value_loss           | 347         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.7          |
# |    ep_rew_mean          | -27.9        |
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 5            |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0077752382 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.57         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 126          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00665     |
# |    value_loss           | 246          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.06       |
# |    ep_rew_mean          | -38        |
# | time/                   |            |
# |    fps                  | 440        |
# |    iterations           | 6          |
# |    time_elapsed         | 222        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.01136465 |
# |    clip_fraction        | 0.0555     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.614      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 124        |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00655   |
# |    value_loss           | 240        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.2         |
# |    ep_rew_mean          | -33.4        |
# | time/                   |              |
# |    fps                  | 449          |
# |    iterations           | 7            |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0057356553 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 84.7         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00626     |
# |    value_loss           | 191          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17.1         |
# |    ep_rew_mean          | -32.9        |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 8            |
# |    time_elapsed         | 282          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0073958244 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 107          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00649     |
# |    value_loss           | 158          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.2         |
# |    ep_rew_mean          | -26.6        |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 9            |
# |    time_elapsed         | 305          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0065383175 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.678        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.9         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00644     |
# |    value_loss           | 124          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.8        |
# |    ep_rew_mean          | -30.7       |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 10          |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.007978019 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0073     |
# |    value_loss           | 123         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.6         |
# |    ep_rew_mean          | -25.2        |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 11           |
# |    time_elapsed         | 352          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0048745256 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.704        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26           |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0054      |
# |    value_loss           | 93.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.3        |
# |    ep_rew_mean          | -25.8       |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 12          |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.005416184 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 71.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.5        |
# |    ep_rew_mean          | -27         |
# | time/                   |             |
# |    fps                  | 540         |
# |    iterations           | 13          |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.006186558 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70          |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 67.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 54           |
# |    ep_rew_mean          | -24.2        |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 14           |
# |    time_elapsed         | 413          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0057862913 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.586        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.6         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00545     |
# |    value_loss           | 65           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.7         |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 15           |
# |    time_elapsed         | 431          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0053824475 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.496        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.89         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00433     |
# |    value_loss           | 32.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.5        |
# |    ep_rew_mean          | -17.6       |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 16          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.008372478 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.02        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 21          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61.1         |
# |    ep_rew_mean          | -15.6        |
# | time/                   |              |
# |    fps                  | 594          |
# |    iterations           | 17           |
# |    time_elapsed         | 468          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0053685405 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | 0.507        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.85         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00286     |
# |    value_loss           | 13.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81           |
# |    ep_rew_mean          | -17          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 18           |
# |    time_elapsed         | 488          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0042272536 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.977       |
# |    explained_variance   | 0.352        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.47         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 23.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.5         |
# |    ep_rew_mean          | -17          |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 19           |
# |    time_elapsed         | 507          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0055840425 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.937       |
# |    explained_variance   | 0.402        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.97         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 14.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.2        |
# |    ep_rew_mean          | -15.2       |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 20          |
# |    time_elapsed         | 525         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.007979035 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.6        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00241    |
# |    value_loss           | 9.33        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | -17.2        |
# | time/                   |              |
# |    fps                  | 633          |
# |    iterations           | 21           |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0054804515 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.955       |
# |    explained_variance   | 0.657        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.83         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 8.54         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | -17.5       |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 22          |
# |    time_elapsed         | 559         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.005352768 |
# |    clip_fraction        | 0.045       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.73        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 7.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | -17.8       |
# | time/                   |             |
# |    fps                  | 653         |
# |    iterations           | 23          |
# |    time_elapsed         | 576         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.003964704 |
# |    clip_fraction        | 0.0511      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.78        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00184    |
# |    value_loss           | 5.69        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 151          |
# |    ep_rew_mean          | -19          |
# | time/                   |              |
# |    fps                  | 664          |
# |    iterations           | 24           |
# |    time_elapsed         | 591          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0077995313 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.919       |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.05         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 5.04         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 154        |
# |    ep_rew_mean          | -21.8      |
# | time/                   |            |
# |    fps                  | 675        |
# |    iterations           | 25         |
# |    time_elapsed         | 606        |
# |    total_timesteps      | 409600     |
# | train/                  |            |
# |    approx_kl            | 0.00460714 |
# |    clip_fraction        | 0.0503     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.922     |
# |    explained_variance   | 0.86       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.62       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00238   |
# |    value_loss           | 3.68       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 169          |
# |    ep_rew_mean          | -19.6        |
# | time/                   |              |
# |    fps                  | 685          |
# |    iterations           | 26           |
# |    time_elapsed         | 620          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0055974135 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.935       |
# |    explained_variance   | 0.896        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.49         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 2.69         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 171        |
# |    ep_rew_mean          | -18.9      |
# | time/                   |            |
# |    fps                  | 693        |
# |    iterations           | 27         |
# |    time_elapsed         | 637        |
# |    total_timesteps      | 442368     |
# | train/                  |            |
# |    approx_kl            | 0.00683421 |
# |    clip_fraction        | 0.05       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.907     |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.18       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00102   |
# |    value_loss           | 2.76       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 140          |
# |    ep_rew_mean          | -15.8        |
# | time/                   |              |
# |    fps                  | 703          |
# |    iterations           | 28           |
# |    time_elapsed         | 651          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0057633123 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.875       |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.74         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 3.08         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | -17         |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 29          |
# |    time_elapsed         | 668         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.005104158 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.000131    |
# |    value_loss           | 6.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | -17.1       |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 30          |
# |    time_elapsed         | 682         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.005709743 |
# |    clip_fraction        | 0.049       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00113    |
# |    value_loss           | 3.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 163         |
# |    ep_rew_mean          | -15.7       |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 31          |
# |    time_elapsed         | 699         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.005033835 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.654       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 3.43        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 149          |
# |    ep_rew_mean          | -15.8        |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 32           |
# |    time_elapsed         | 713          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0039288523 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.829       |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.616        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000316    |
# |    value_loss           | 3.02         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | -17.8        |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 33           |
# |    time_elapsed         | 727          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0054494804 |
# |    clip_fraction        | 0.0426       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.793       |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.885        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 3.21         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | -19.2        |
# | time/                   |              |
# |    fps                  | 749          |
# |    iterations           | 34           |
# |    time_elapsed         | 742          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0037674748 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 4.74         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 178         |
# |    ep_rew_mean          | -18.1       |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 35          |
# |    time_elapsed         | 756         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.004505541 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.685       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.000372    |
# |    value_loss           | 3.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | -19.2       |
# | time/                   |             |
# |    fps                  | 763         |
# |    iterations           | 36          |
# |    time_elapsed         | 772         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.005221137 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000878   |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 37          |
# |    time_elapsed         | 785         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.003457944 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.8        |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.598       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.000222    |
# |    value_loss           | 1.92        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 210        |
# |    ep_rew_mean          | -18.6      |
# | time/                   |            |
# |    fps                  | 776        |
# |    iterations           | 38         |
# |    time_elapsed         | 802        |
# |    total_timesteps      | 622592     |
# | train/                  |            |
# |    approx_kl            | 0.00548416 |
# |    clip_fraction        | 0.0436     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.797     |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.82       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00149   |
# |    value_loss           | 3.95       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | -18.1       |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 39          |
# |    time_elapsed         | 818         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.007859342 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.44        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000461   |
# |    value_loss           | 2.07        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -19.4        |
# | time/                   |              |
# |    fps                  | 786          |
# |    iterations           | 40           |
# |    time_elapsed         | 832          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0059282677 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.829       |
# |    explained_variance   | 0.875        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.625        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 2.88         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 185          |
# |    ep_rew_mean          | -20.6        |
# | time/                   |              |
# |    fps                  | 794          |
# |    iterations           | 41           |
# |    time_elapsed         | 845          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0040757246 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.819       |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 1.99         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 190          |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 801          |
# |    iterations           | 42           |
# |    time_elapsed         | 858          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0042556617 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.807       |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.383        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 1.9          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 195          |
# |    ep_rew_mean          | -20.9        |
# | time/                   |              |
# |    fps                  | 808          |
# |    iterations           | 43           |
# |    time_elapsed         | 871          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0038444342 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.773       |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.49         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000208    |
# |    value_loss           | 1.53         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 44           |
# |    time_elapsed         | 886          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0055529005 |
# |    clip_fraction        | 0.0522       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.788       |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.596        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 4.51         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 204          |
# |    ep_rew_mean          | -20.1        |
# | time/                   |              |
# |    fps                  | 819          |
# |    iterations           | 45           |
# |    time_elapsed         | 900          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0034569358 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.468        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000833    |
# |    value_loss           | 2.39         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 204          |
# |    ep_rew_mean          | -22.3        |
# | time/                   |              |
# |    fps                  | 824          |
# |    iterations           | 46           |
# |    time_elapsed         | 914          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0036178224 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.719       |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.372        |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000258    |
# |    value_loss           | 1.44         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 205          |
# |    ep_rew_mean          | -20.8        |
# | time/                   |              |
# |    fps                  | 829          |
# |    iterations           | 47           |
# |    time_elapsed         | 927          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0033211943 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.715       |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.976        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000512    |
# |    value_loss           | 2.02         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 191          |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 834          |
# |    iterations           | 48           |
# |    time_elapsed         | 942          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0034709221 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.306        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000756    |
# |    value_loss           | 1.38         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 167          |
# |    ep_rew_mean          | -19          |
# | time/                   |              |
# |    fps                  | 839          |
# |    iterations           | 49           |
# |    time_elapsed         | 956          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0057617114 |
# |    clip_fraction        | 0.0372       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.741       |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.611        |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 2.65         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 191          |
# |    ep_rew_mean          | -20.1        |
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 50           |
# |    time_elapsed         | 970          |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0043650516 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.679       |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.03         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000557    |
# |    value_loss           | 2.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 171          |
# |    ep_rew_mean          | -18.6        |
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 51           |
# |    time_elapsed         | 984          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0033353437 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.699       |
# |    explained_variance   | 0.886        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000686    |
# |    value_loss           | 3.13         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | -18.1       |
# | time/                   |             |
# |    fps                  | 855         |
# |    iterations           | 52          |
# |    time_elapsed         | 996         |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.004764734 |
# |    clip_fraction        | 0.0461      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.55        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 2.74        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | -18.7        |
# | time/                   |              |
# |    fps                  | 858          |
# |    iterations           | 53           |
# |    time_elapsed         | 1011         |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0038890403 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.676       |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000656    |
# |    value_loss           | 4.41         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | -17.7       |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 54          |
# |    time_elapsed         | 1024        |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.004731685 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.481       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.000558   |
# |    value_loss           | 2.26        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 171          |
# |    ep_rew_mean          | -17.3        |
# | time/                   |              |
# |    fps                  | 866          |
# |    iterations           | 55           |
# |    time_elapsed         | 1039         |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0034468188 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.548       |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.54         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 2.41         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | -17.7        |
# | time/                   |              |
# |    fps                  | 869          |
# |    iterations           | 56           |
# |    time_elapsed         | 1055         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0036959145 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.549       |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.42         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.000578    |
# |    value_loss           | 2.2          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | -18.8       |
# | time/                   |             |
# |    fps                  | 872         |
# |    iterations           | 57          |
# |    time_elapsed         | 1070        |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.003024898 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.541      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.919       |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00175    |
# |    value_loss           | 2.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 201         |
# |    ep_rew_mean          | -18.9       |
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 58          |
# |    time_elapsed         | 1086        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.003072076 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.476       |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.000482   |
# |    value_loss           | 1.62        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 191          |
# |    ep_rew_mean          | -20.5        |
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 59           |
# |    time_elapsed         | 1098         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0032873435 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.44         |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.000489    |
# |    value_loss           | 1.77         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 168          |
# |    ep_rew_mean          | -19.2        |
# | time/                   |              |
# |    fps                  | 883          |
# |    iterations           | 60           |
# |    time_elapsed         | 1112         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0034658506 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.622        |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.000849    |
# |    value_loss           | 2.62         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 183          |
# |    ep_rew_mean          | -20.7        |
# | time/                   |              |
# |    fps                  | 888          |
# |    iterations           | 61           |
# |    time_elapsed         | 1125         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0026409933 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | 0.893        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.381        |
# |    n_updates            | 600          |
# |    policy_gradient_loss | 0.000412     |
# |    value_loss           | 2.98         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | -19.6        |
# | time/                   |              |
# |    fps                  | 891          |
# |    iterations           | 62           |
# |    time_elapsed         | 1139         |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0028730868 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 0.901        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.454        |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.000637    |
# |    value_loss           | 2.24         |
# ------------------------------------------
# [INFO] Model saved to /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImprAB_a88ac_1M.zip
# [INFO] Dataset already exists:
# /Users/preetkaria/PycharmProjects/when_to_leave/data/c08ec_10K.pkl

# %%
from pandarallel import pandarallel

# Initialize pandarallel with progress bar enabled
pandarallel.initialize(progress_bar=True)

columns_to_visualize = []
for model in model_approaches:
    print(f'Evaluating {model.prediction_keys()}')
    columns_to_visualize += model.prediction_keys()
    
    new_cols = test_df.parallel_apply(lambda row: model.predict(row, override=False), result_type='expand', axis=1)
    for i, col_name in enumerate(model.prediction_keys()):
        test_df[col_name] = new_cols[i]
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# Evaluating ['cost_PPO_EnvImprAB_a88ac_1M', 'observed_n_PPO_EnvImprAB_a88ac_1M']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Var_n', 'observed_n_Oracle_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Var_n', 'observed_n_PTO_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …

# %%
from pathlib import Path
test_df_path = Path(test_df_path)
test_df.to_csv(test_df_path.with_suffix('.csv'), index=False)
test_df.to_pickle(test_df_path)

# %% [markdown]
# ## Visualize Results

# %%
import plotly.graph_objects as go

# columns_to_visualize = [x for x in test_df.columns if 'cost' in x or 'observe' in x]

# Calculate means
means = test_df[columns_to_visualize + ['h', 'c']].mean()

# Plot
fig = go.Figure(data=[go.Bar(x=means.index, y=means.values)])
fig.update_layout(title="Mean Values of Costs, H, and C", yaxis_title="Mean Value")
fig.show()

# Calculate medians
medians = test_df[columns_to_visualize + ['h', 'c']].median()

# Plot
fig = go.Figure(data=[go.Bar(x=medians.index, y=medians.values)])
fig.update_layout(title="Median Values of Costs, H, and C", yaxis_title="Median Value")
fig.show()

# Create a dataframe with two rows: one for means and one for medians
summary_df = pd.DataFrame({'Mean': means, 'Median': medians}).T
summary_df.head()
# Out:
#         cost_PPO_EnvImprAB_a88ac_1M  observed_n_PPO_EnvImprAB_a88ac_1M  \
# Mean                      18.927639                            20.5882
# Median                    25.000000                            20.0000
#
#         cost_Oracle_Var_n  observed_n_Oracle_Var_n  cost_PTO_Var_n  \
# Mean             9.271882                  11.0837       11.196373
# Median           7.398280                   9.0000        7.646752
#
#         observed_n_PTO_Var_n  cost_PTO_Fix_n_3  cost_PTO_Fix_n_5  \
# Mean                 11.1163         18.001524         16.846946
# Median                9.0000         20.512448         18.606267
#
#         cost_Oracle_Fix_n_3  cost_Oracle_Fix_n_5    h     c
# Mean              10.710248            11.957163  0.5  25.0
# Median             8.060416             8.944021  0.5  25.0
