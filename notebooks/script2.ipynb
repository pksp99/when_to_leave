# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Box, Sequence, Dict
import numpy as np
import pandas as pd
from src.commons import methods
import statistics

from src.rl_environments.env_impr import EnvImpr
from src.model_approaches.analytical.oracle_fix_n import OracleFix_n
from src.model_approaches.analytical.oracle_var_n import OracleVar_n
from src.model_approaches.analytical.pto_fix_n import PTO_Fix_n
from src.model_approaches.analytical.pto_var_n import PTO_Var_n
from src.model_approaches.rl.ppo import PPO

from src.commons import generate_data
from src.commons.constants import AlphaEstimator, TravelTimeDist
import os
import pickle

# %% [markdown]
# ## Config

# %%
TRAIN_CONFIG = {
    'alpha_range': [ (1 + i / 10) for i in range(1,10)],
    'beta_range': [round(i * 0.5, 1) for i in range(2, 6)],
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MAX_LIKELI,
}

TEST_CONFIG = {
    'alpha_range': [ (3 + i / 10) for i in range(1,10)],
    'beta_range': [round(i * 0.5, 1) for i in range(2, 6)],
    'h_range': [0.5],
    'c_range': [25],
    'total': list(range(10, 40)),
    'travel_time': TravelTimeDist.UNIFORM,
    'param_estimator': AlphaEstimator.MAX_LIKELI,
}

# %%
model_approaches = [PPO(EnvClass=EnvImpr, config=TRAIN_CONFIG, timesteps=500_000),
                    OracleVar_n(),
                    PTO_Var_n(TEST_CONFIG)
                   ] + [PTO_Fix_n(n, TEST_CONFIG) for n in [3, 5]] + [OracleFix_n(n) for n in [3, 5]]
test_df_path = generate_data.generate(config=TEST_CONFIG, row_count=10_000)
test_df = pd.DataFrame()
with open(test_df_path, 'rb') as f:
    test_df =pickle.load(f)
# Out:
# [INFO] Training PPO model...
# Saving to: /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImpr_b73d3_500K.zip
# [INFO] Launching training with 8 parallel environments
# Using cpu device
# [INFO] Training PPO for 500000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.17     |
# |    ep_rew_mean     | -14      |
# | time/              |          |
# |    fps             | 491      |
# |    iterations      | 1        |
# |    time_elapsed    | 33       |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.05        |
# |    ep_rew_mean          | -13.8       |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 2           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010556612 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0128      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.7        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 90.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.16        |
# |    ep_rew_mean          | -14.6       |
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 3           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010321932 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 67.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.13        |
# |    ep_rew_mean          | -13         |
# | time/                   |             |
# |    fps                  | 518         |
# |    iterations           | 4           |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007734095 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00429    |
# |    value_loss           | 60.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.3         |
# |    ep_rew_mean          | -13.6       |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 5           |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011130303 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 59.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.59       |
# |    ep_rew_mean          | -13.3      |
# | time/                   |            |
# |    fps                  | 550        |
# |    iterations           | 6          |
# |    time_elapsed         | 178        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00887925 |
# |    clip_fraction        | 0.0566     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | 0.476      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 37.6       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00472   |
# |    value_loss           | 52.7       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.8         |
# |    ep_rew_mean          | -13.2        |
# | time/                   |              |
# |    fps                  | 561          |
# |    iterations           | 7            |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0103171645 |
# |    clip_fraction        | 0.0652       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.481        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.5         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0061      |
# |    value_loss           | 51           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.6        |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 8           |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.006573342 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 40.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.4        |
# |    ep_rew_mean          | -12.2       |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 9           |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.007078556 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.8        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00639    |
# |    value_loss           | 42.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.6       |
# |    ep_rew_mean          | -11.1      |
# | time/                   |            |
# |    fps                  | 600        |
# |    iterations           | 10         |
# |    time_elapsed         | 272        |
# |    total_timesteps      | 163840     |
# | train/                  |            |
# |    approx_kl            | 0.00501566 |
# |    clip_fraction        | 0.0441     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | 0.453      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31.3       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00551   |
# |    value_loss           | 38.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.5         |
# |    ep_rew_mean          | -13          |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 11           |
# |    time_elapsed         | 292          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0038780333 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.432        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.6         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00461     |
# |    value_loss           | 32.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.2        |
# |    ep_rew_mean          | -12.4       |
# | time/                   |             |
# |    fps                  | 634         |
# |    iterations           | 12          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.005831304 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 30.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.6         |
# |    ep_rew_mean          | -10.6        |
# | time/                   |              |
# |    fps                  | 649          |
# |    iterations           | 13           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0049537933 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.359        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.8         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00486     |
# |    value_loss           | 26.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -11.4       |
# | time/                   |             |
# |    fps                  | 667         |
# |    iterations           | 14          |
# |    time_elapsed         | 343         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.012324386 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0041     |
# |    value_loss           | 22.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -12.7        |
# | time/                   |              |
# |    fps                  | 683          |
# |    iterations           | 15           |
# |    time_elapsed         | 359          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0069178627 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.344        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.57         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 17.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.2        |
# |    ep_rew_mean          | -9.38       |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 16          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.009689827 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.255       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.36        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00354    |
# |    value_loss           | 16.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.2        |
# |    ep_rew_mean          | -11.2       |
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 17          |
# |    time_elapsed         | 408         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.008310745 |
# |    clip_fraction        | 0.0498      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.64        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 9.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.2        |
# |    ep_rew_mean          | -7.98       |
# | time/                   |             |
# |    fps                  | 675         |
# |    iterations           | 18          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.004799178 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.49        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00261    |
# |    value_loss           | 9.92        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 62.1         |
# |    ep_rew_mean          | -8.25        |
# | time/                   |              |
# |    fps                  | 671          |
# |    iterations           | 19           |
# |    time_elapsed         | 463          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0029835065 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.122        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.87         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000555    |
# |    value_loss           | 10.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 76.1         |
# |    ep_rew_mean          | -8.6         |
# | time/                   |              |
# |    fps                  | 668          |
# |    iterations           | 20           |
# |    time_elapsed         | 490          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0026632268 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.856       |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.1          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000428    |
# |    value_loss           | 6.99         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.9         |
# |    ep_rew_mean          | -8.38        |
# | time/                   |              |
# |    fps                  | 665          |
# |    iterations           | 21           |
# |    time_elapsed         | 517          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0018830501 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.916       |
# |    explained_variance   | 0.249        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000529    |
# |    value_loss           | 7.48         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.5        |
# |    ep_rew_mean          | -9.43       |
# | time/                   |             |
# |    fps                  | 665         |
# |    iterations           | 22          |
# |    time_elapsed         | 541         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.002620323 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000496   |
# |    value_loss           | 6.19        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 62.3         |
# |    ep_rew_mean          | -7.16        |
# | time/                   |              |
# |    fps                  | 663          |
# |    iterations           | 23           |
# |    time_elapsed         | 568          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0049107587 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.276        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.53         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 7.85         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 64.3         |
# |    ep_rew_mean          | -10.3        |
# | time/                   |              |
# |    fps                  | 659          |
# |    iterations           | 24           |
# |    time_elapsed         | 596          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0041356767 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.914       |
# |    explained_variance   | 0.349        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.7          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 8.08         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.8         |
# |    ep_rew_mean          | -10.3        |
# | time/                   |              |
# |    fps                  | 653          |
# |    iterations           | 25           |
# |    time_elapsed         | 627          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0029159728 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.864       |
# |    explained_variance   | 0.362        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.31         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000713    |
# |    value_loss           | 7.91         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60.9         |
# |    ep_rew_mean          | -9.18        |
# | time/                   |              |
# |    fps                  | 653          |
# |    iterations           | 26           |
# |    time_elapsed         | 651          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0031281258 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.853       |
# |    explained_variance   | 0.394        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.84         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 9.04         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.5         |
# |    ep_rew_mean          | -7.89        |
# | time/                   |              |
# |    fps                  | 651          |
# |    iterations           | 27           |
# |    time_elapsed         | 678          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0020064581 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.786       |
# |    explained_variance   | 0.458        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.6          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000576    |
# |    value_loss           | 8.75         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.6         |
# |    ep_rew_mean          | -7.67        |
# | time/                   |              |
# |    fps                  | 650          |
# |    iterations           | 28           |
# |    time_elapsed         | 705          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0039062295 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.742       |
# |    explained_variance   | 0.503        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.743        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -3.15e-05    |
# |    value_loss           | 6.45         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79.9         |
# |    ep_rew_mean          | -7.6         |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 29           |
# |    time_elapsed         | 734          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0030427952 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.818       |
# |    explained_variance   | 0.473        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.54         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.000161     |
# |    value_loss           | 5.96         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 71.7         |
# |    ep_rew_mean          | -7.36        |
# | time/                   |              |
# |    fps                  | 644          |
# |    iterations           | 30           |
# |    time_elapsed         | 762          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0036457009 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.758       |
# |    explained_variance   | 0.489        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.18         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000983    |
# |    value_loss           | 6.58         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 80.8         |
# |    ep_rew_mean          | -7.61        |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 31           |
# |    time_elapsed         | 785          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0021095974 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.74        |
# |    explained_variance   | 0.44         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -1.88e-05    |
# |    value_loss           | 6.62         |
# ------------------------------------------
# [INFO] Model saved to /Users/preetkaria/PycharmProjects/when_to_leave/models/PPO_EnvImpr_b73d3_500K.zip
# [INFO] Generating new dataset:
# /Users/preetkaria/PycharmProjects/when_to_leave/data/c08ec_10K

# %%
from pandarallel import pandarallel

# Initialize pandarallel with progress bar enabled
pandarallel.initialize(progress_bar=True)

columns_to_visualize = []
for model in model_approaches:
    print(f'Evaluating {model.prediction_keys()}')
    columns_to_visualize += model.prediction_keys()
    
    new_cols = test_df.parallel_apply(lambda row: model.predict(row, override=False), result_type='expand', axis=1)
    for i, col_name in enumerate(model.prediction_keys()):
        test_df[col_name] = new_cols[i]
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# Evaluating ['cost_PPO_EnvImpr_b73d3_500K', 'observed_n_PPO_EnvImpr_b73d3_500K']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Var_n', 'observed_n_Oracle_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Var_n', 'observed_n_PTO_Var_n']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_PTO_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_3']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …
# Evaluating ['cost_Oracle_Fix_n_5']
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1250), Label(value='0 / 1250'))), …

# %%
from pathlib import Path
test_df_path = Path(test_df_path)
test_df.to_csv(test_df_path.with_suffix('.csv'), index=False)
test_df.to_pickle(test_df_path)

# %% [markdown]
# ## Visualize Results

# %%
import plotly.graph_objects as go

# columns_to_visualize = [x for x in test_df.columns if 'cost' in x or 'observe' in x]

# Calculate means
means = test_df[columns_to_visualize + ['h', 'c']].mean()

# Plot
fig = go.Figure(data=[go.Bar(x=means.index, y=means.values)])
fig.update_layout(title="Mean Values of Costs, H, and C", yaxis_title="Mean Value")
fig.show()

# Calculate medians
medians = test_df[columns_to_visualize + ['h', 'c']].median()

# Plot
fig = go.Figure(data=[go.Bar(x=medians.index, y=medians.values)])
fig.update_layout(title="Median Values of Costs, H, and C", yaxis_title="Median Value")
fig.show()

# Create a dataframe with two rows: one for means and one for medians
summary_df = pd.DataFrame({'Mean': means, 'Median': medians}).T
summary_df.head()
# Out:
#         cost_PPO_EnvImpr_b73d3_500K  observed_n_PPO_EnvImpr_b73d3_500K  \
# Mean                      12.230326                            11.9027
# Median                     7.981996                            10.0000
#
#         cost_Oracle_Var_n  observed_n_Oracle_Var_n  cost_PTO_Var_n  \
# Mean             9.271882                  11.0837       11.196373
# Median           7.398280                   9.0000        7.646752
#
#         observed_n_PTO_Var_n  cost_PTO_Fix_n_3  cost_PTO_Fix_n_5  \
# Mean                 11.1163         18.001524         16.846946
# Median                9.0000         20.512448         18.606267
#
#         cost_Oracle_Fix_n_3  cost_Oracle_Fix_n_5    h     c
# Mean              10.710248            11.957163  0.5  25.0
# Median             8.060416             8.944021  0.5  25.0
